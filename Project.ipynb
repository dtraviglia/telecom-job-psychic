# %% [markdown]
# # Prediction of Repair Dispatch Job Demand
#
# ### for Resource and Capacity Management of Telecommunication Services
#
# Due: Friday, December 10, 2014 11:59 PM
#
# #### Project Overview
# Telecom services, such as voice, data, and video services, are delivered on various telecommunication networks to subscribers’ homes and businesses.  Failures and operating problems associated with the network and network equipment cause service problems in which some of them can be fixed remotely and others require dispatch of technicians to the site to repair and fix the problem(s).   Managing the available resources and their capacity in executing the repair jobs is quite challenging because the daily volume of dispatch needs (jobs demand) is largely unpredictable due to several factors such as the characteristics of the network and network equipment, nature of repairs needed, regulations, weather, seasonality, and characteristics of the labor force (such as union membership, skills, culture); among others.   On the other hand, if extra resources and capacity is secured, the cost to secure resources in addition to unplanned overtime cost can be substantial.  If a lack of resources and capacity exists, then broken promises and negative customer experiences occur which affect customer satisfaction.  The ability to predict the jobs demand in advance for immediate and near short terms can provide substantial benefits in optimizing capacity, reducing network downtime and improving customer satisfaction.
#
# Project Milestones | Final Date
# :---: | :---:
# Completion of the project review meeting with TE | 11/21/14
# Completion of the raw data collection and processing | 11/28/14
# Completion of model development and testing | 12/05/14
# Completion of IPython Process book | 12/10/14
# Completion of Screencast and Webpage | 12/12/14
# Completion of project presentation | 12/16/14
#
# ---

# %% [markdown]
# ## About Data
#
# The data source includes:
# - Historical repair/dispatch jobs on daily basis from January 1, 2013 to October 21, 2014.
# - Historical weather data (cover many parameters such as temperature, wind, percipitation, conditions, etc.,) from January 1, 2013 to October 21, 2014.
# - Reference data on national and local holidays applicable to the repairs centers.
#
# The weather data is commercially available from Accuweather and the jobs data are available from a major telecom provider for two independent geographical service areas.
#
# - 02116 - Boston, Massachusetts
# - 02865 - Lincoln, Rhode Island
#
# ---

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd # pandas
import matplotlib.pyplot as plt # module for plotting 
import datetime as dt # module for manipulating dates and times

import sklearn
from sklearn import linear_model
from sklearn import metrics

import sklearn.cross_validation
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score

import seaborn as sns
sns.set_style("white")

# special matplotlib argument for improved plots
from matplotlib import rcParams

#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'

# %% [markdown]
# ## Data Wrangling
#
# Read the data from excel sheet into Pandas dataframe(s)

# %%
#read the data from excel file into pandas
DispatchData = pd.ExcelFile("Data.xlsx")

#print all the sheets
print DispatchData.sheet_names
# Out:
# [u'02865', u'02116']

# %%
#load the data from each sheet into Pandas dataframe
dfBos = DispatchData.parse("02116", index_col='JOBCREATEDATE')

#show the head of the dataframe
dfBos.head()
# Out:
#                Repaircenterid REGIONNAME  COREJOBS  FIBERJOBS   ZIP  HI_TEMP  \
# JOBCREATEDATE
# 2013-01-01             500001         NE         0          0  2116       37
# 2013-01-02             500001         NE         0          0  2116       30
# 2013-01-03             500001         NE         2          1  2116       25
# 2013-01-04             500001         NE         1          0  2116       38
# 2013-01-05             500001         NE         0          0  2116       42
#
#                LOW_TEMP_F  DFN_HI_TEMP_F  DFN_LOW_TEMP_F  MAX_HEAT_IDX_TEMP_F  \
# JOBCREATEDATE
# 2013-01-01             19             -1              -6                   36
# 2013-01-02             10             -8             -14                   29
# 2013-01-03              7            -13             -17                   25
# 2013-01-04             21              0              -3                   37
# 2013-01-05             27              4               3                   41
#
#                    ...             WX_TEXT  FLOOD1_FLG  FLOOD2_FLG  \
# JOBCREATEDATE      ...
# 2013-01-01         ...       Mostly Cloudy           0           0
# 2013-01-02         ...               Clear           0           0
# 2013-01-03         ...       Partly Cloudy           0           0
# 2013-01-04         ...       Mostly Cloudy           0           0
# 2013-01-05         ...       Mostly Cloudy           0           0
#
#                EXTM_WIND_FLG  EXTM_WIND_SPEED_MPH  POWER_OUTAGE_FLG  \
# JOBCREATEDATE
# 2013-01-01                 0                    0                 0
# 2013-01-02                 0                    0                 0
# 2013-01-03                 0                    0                 0
# 2013-01-04                 0                    0                 0
# 2013-01-05                 0                    0                 0
#
#                POWER_OUTAGE_WIND_FLG  W_Score         Holiday Major_Holiday
# JOBCREATEDATE
# 2013-01-01                         0        0  New Year's Day             M
# 2013-01-02                         0        0               N             N
# 2013-01-03                         0        0               N             N
# 2013-01-04                         0        0               N             N
# 2013-01-05                         0        0               N             N
#
# [5 rows x 30 columns]

# %%
#load the data from each sheet into Pandas dataframe
dfLin = DispatchData.parse("02865", index_col='JOBCREATEDATE')

#show the head of the dataframe
dfLin.head()
# Out:
#                Repaircenterid REGIONNAME  COREJOBS  FIBERJOBS   ZIP  HI_TEMP  \
# JOBCREATEDATE
# 2013-01-01             100001         NE         2          4  2865       36
# 2013-01-02             100001         NE         1          7  2865       30
# 2013-01-03             100001         NE         6          2  2865       23
# 2013-01-04             100001         NE         3          5  2865       37
# 2013-01-05             100001         NE         1          3  2865       39
#
#                LOW_TEMP_F  DFN_HI_TEMP_F  DFN_LOW_TEMP_F  MAX_HEAT_IDX_TEMP_F  \
# JOBCREATEDATE
# 2013-01-01             19             -3              -3                   34
# 2013-01-02             10             -8             -12                   28
# 2013-01-03              7            -15             -15                   23
# 2013-01-04             21             -1              -1                   37
# 2013-01-05             21              1              -1                   39
#
#                    ...             WX_TEXT  FLOOD1_FLG  FLOOD2_FLG  \
# JOBCREATEDATE      ...
# 2013-01-01         ...       Mostly Cloudy           0           0
# 2013-01-02         ...               Clear           0           0
# 2013-01-03         ...               Clear           0           0
# 2013-01-04         ...               Clear           0           0
# 2013-01-05         ...               Clear           0           0
#
#                EXTM_WIND_FLG  EXTM_WIND_SPEED_MPH  POWER_OUTAGE_FLG  \
# JOBCREATEDATE
# 2013-01-01                 0                    0                 0
# 2013-01-02                 0                    0                 0
# 2013-01-03                 0                    0                 0
# 2013-01-04                 0                    0                 0
# 2013-01-05                 0                    0                 0
#
#                POWER_OUTAGE_WIND_FLG  W_Score         Holiday Major_Holiday
# JOBCREATEDATE
# 2013-01-01                         0        0  New Year's Day             M
# 2013-01-02                         0        0               N             N
# 2013-01-03                         0        0               N             N
# 2013-01-04                         0        0               N             N
# 2013-01-05                         0        0               N             N
#
# [5 rows x 30 columns]

# %%
#print the name of the columns
dfBos.columns = [x.lower() for x in dfBos.columns]
dfBos.columns

dfLin.columns = [x.lower() for x in dfLin.columns]
dfLin.columns
# Out:
# Index([u'repaircenterid', u'regionname', u'corejobs', u'fiberjobs', u'zip', u'hi_temp', u'low_temp_f', u'dfn_hi_temp_f', u'dfn_low_temp_f', u'max_heat_idx_temp_f', u'min_heat_idx_temp_f', u'max_sust_wind_speed_mph', u'max_gust_mph', u'pcpn_poss_percent', u'pcpn_amt_inch', u'norm_pcpn_amt_inch', u'snwfl_amt_inch', u'norm_snwfl_amt_inch', u'2_digit_wx', u'wx_code', u'wx_text', u'flood1_flg', u'flood2_flg', u'extm_wind_flg', u'extm_wind_speed_mph', u'power_outage_flg', u'power_outage_wind_flg', u'w_score', u'holiday', u'major_holiday'], dtype='object')

# %%
print dfBos.shape
print dfLin.shape
# Out:
# (5897, 30)
# (4592, 30)

# %%
#handling missing weather data discuss fillna (fwd/bwd fill and interpolation methods)
#why interpolate doesnt work check???
#dfBos['hi_temp'].fillna(np.mean)

dfBos = dfBos.interpolate(method='time')
dfLin = dfLin.interpolate(method='time')

# %%
dfBos = dfBos.dropna()
dfLin = dfLin.dropna()

print dfBos.shape
print dfLin.shape
# Out:
# (5841, 30)
# (4543, 30)

# %%
#The day of the week with Monday=0, Sunday=6
weekday = {0: 'Mon', 1: 'Tue', 2: 'Wed', 3: 'Thur', 4: 'Fri', 5: 'Sat', 6: 'Sun'}

#create new columns year, month, dayofweek, day
dfBos['year'] = map(lambda x: int(x), dfBos.index.year)
dfBos['month'] = map(lambda x: int(x), dfBos.index.month)
dfBos['dayofweek'] = map(lambda x: int(x), dfBos.index.dayofweek)
dfBos['weekday'] = map(lambda x: weekday[x], dfBos.index.dayofweek)
dfBos['day'] = map(lambda x: int(x), dfBos.index.day)
dfBos['d'] = dfBos.index - pd.Timestamp('20140930')

#create new columns year, month, dayofweek, day
dfLin['year'] = map(lambda x: int(x), dfLin.index.year)
dfLin['month'] = map(lambda x: int(x), dfLin.index.month)
dfLin['dayofweek'] = map(lambda x: int(x), dfLin.index.dayofweek)
dfLin['weekday'] = map(lambda x: weekday[x], dfLin.index.dayofweek)
dfLin['day'] = map(lambda x: int(x), dfLin.index.day)
dfLin['d'] = dfLin.index - pd.Timestamp('20140930')

# %% [markdown]
# ## Exploratory Data Analysis
#
# Explore the dataset and find any pattern or co-relations exist between variables

# %%
#distribution of Core & Fiber jobs per zipcode

plt.figure(figsize=(10,8))

plt.subplot(2, 2, 1)
plt.hist(dfBos.corejobs)
plt.title("Boston - Core Jobs Distribution")
plt.xlabel("Core Jobs")
plt.ylabel("Frequency")
    
plt.subplot(2, 2, 2)
plt.hist(dfBos.fiberjobs)
plt.title("Boston - Fiber Jobs Distribution")
plt.xlabel("Fiber Jobs")
plt.ylabel("Frequency")

plt.subplot(2, 2, 3)
plt.hist(dfLin.corejobs)
plt.title("Lincoln - Core Jobs Distribution")
plt.xlabel("Core Jobs")
plt.ylabel("Frequency")
    
plt.subplot(2, 2, 4)
plt.hist(dfLin.fiberjobs)
plt.title("Lincoln - Fiber Jobs Distribution")
plt.xlabel("Fiber Jobs")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Write the reasons for choosing Boston Core Jobs for further analysis
#
# Due to blah blah....

# %%
#correlation matrix between all "weather" input vairables
f, ax = plt.subplots(figsize=(20, 20))
sns.corrplot(dfBos[[u'hi_temp', u'low_temp_f', u'dfn_hi_temp_f', u'dfn_low_temp_f', u'max_heat_idx_temp_f', u'min_heat_idx_temp_f', 
                    u'max_sust_wind_speed_mph', u'max_gust_mph', u'pcpn_poss_percent', u'pcpn_amt_inch', u'norm_pcpn_amt_inch', 
                    u'snwfl_amt_inch', u'norm_snwfl_amt_inch', 'fiberjobs', 'corejobs']], diag_names=False, ax=ax);

# %%
#loop thru each weather column from the data frame
for col in dfBos.columns[5:18]:
    
    #set the plot properties
    plt.figure(figsize=(20,8))
    
    #plt.subplot(4, 4, i)
    plt.title("Weather Parameter(s) vs No.of Jobs")
    plt.xlabel(col)
    plt.ylabel("No of Jobs")
    
    #create a scatter plot with Year and each PA Rate
    plt.scatter(dfBos[col], dfBos['corejobs'], c='g', s=40, alpha=0.5)
    plt.scatter(dfBos[col], dfBos['fiberjobs'], c='r', s=40)
    
    #show the plot
    plt.show()

# %%
#group by the stats dataframe by year (across all teams) and compute the mean of PA rates
dfBosbyCore = dfBos.groupby(['corejobs']).mean()
dfBosbyFiber = dfBos.groupby(['fiberjobs']).mean()

plt.figure(figsize=(20,10))

#loop thru each weather column from the data frame
for col in dfBos.columns[5:18]:
    
    #set the plot properties
    plt.title("Jobs vs Weather Parameter(s)")
    plt.xlabel("No of Jobs")
    plt.ylabel("Weather Parameters")

    #create the plot (line) for each PA rate
    plt.plot(dfBosbyCore.index, dfBosbyCore[col], marker='o', label=col)
    
    plt.legend(loc = 'upper right', bbox_to_anchor = (1, 1))

    #show the plot
    plt.show

# %%
#temperature variables
sns.pairplot(dfBos[[u'hi_temp', u'low_temp_f', u'dfn_hi_temp_f', u'dfn_low_temp_f', u'max_heat_idx_temp_f', u'min_heat_idx_temp_f', 
                    'corejobs', 'fiberjobs']], hue='corejobs')

# %%
#wind and snow fall varaibales
sns.pairplot(dfBos[[u'max_sust_wind_speed_mph', u'max_gust_mph', 'corejobs', 'fiberjobs']], hue='corejobs')

# %%
#percipitation variables
sns.pairplot(dfBos[[u'pcpn_poss_percent', u'pcpn_amt_inch', u'norm_pcpn_amt_inch', 
                    u'snwfl_amt_inch', u'norm_snwfl_amt_inch','corejobs', 'fiberjobs']], hue='corejobs')

# %%
#group by date to combine all repair centers in a zip
dfBoston = dfBos.groupby(dfBos.index).agg({'corejobs' : np.sum,
                               'fiberjobs' : np.sum,
                               'wx_code' : np.max,
                               'holiday' : np.max,
                               'major_holiday' : np.max,
                               'year' : np.max, 
                               'month' : np.max, 
                               'dayofweek' : np.max, 
                               'weekday' : np.max, 
                               'day' : np.max, 
                               'd' : np.max})

#check if the index is unique after group by
print dfBoston.index.is_unique

dfBoston.head()
# Out:
# True
#                dayofweek major_holiday  month  year wx_code  corejobs  \
# JOBCREATEDATE
# 2013-01-01             1             M      1  2013      MC        12
# 2013-01-02             2             N      1  2013     CLR        89
# 2013-01-03             3             N      1  2013      PC        89
# 2013-01-04             4             N      1  2013      MC        79
# 2013-01-05             5             N      1  2013      MC        21
#
#                fiberjobs         d  day weekday         holiday
# JOBCREATEDATE
# 2013-01-01             0 -637 days    1     Tue  New Year's Day
# 2013-01-02             0 -636 days    2     Wed               N
# 2013-01-03             1 -635 days    3    Thur               N
# 2013-01-04             0 -634 days    4     Fri               N
# 2013-01-05             0 -633 days    5     Sat               N

# %%
#day level variance of number of jobs by month by year
g = sns.FacetGrid(dfBoston, row='month', col='year', sharex=False, margin_titles=True, size=6, xlim=(1,31))
g.map(sns.barplot, 'day', 'corejobs', color="steelblue")

# %%
#jobs by holiday year over year
g = sns.FacetGrid(dfBoston, col='year', margin_titles=True, size=8)
g.map(sns.barplot, 'holiday', 'corejobs', color="steelblue")
g.set_xticklabels(rotation=45)

# %%
#jobs by weekday by month by year
g = sns.FacetGrid(dfBoston, row='year', col='month', margin_titles=True, aspect=.5)
g.map(sns.barplot, 'dayofweek','corejobs', color="steelblue")
g.set_xticklabels(labels=['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun'], rotation=45)

# %%
#bar plot month by year
#find out why 11 and 12 is not in 2013
g = sns.FacetGrid(dfBoston, col="year", size=8)
g.map(sns.barplot, "month", "corejobs", color="steelblue");

# %%
#bar plot year by day
g = sns.FacetGrid(dfBoston, col="year", size=8)
g.map(sns.barplot, "day", "corejobs", color="steelblue");

# %%
#bar plot month by major holidays
g = sns.FacetGrid(dfBoston, col="major_holiday", size=6)
g.map(sns.barplot, "day", "corejobs", color="steelblue");

# %% [markdown]
# ## Feature Selection Process
#
# Explain the feature selection process, converting categorical variable into dummy variables, creating lags for a week, etc.,

# %%
#convert categorical variables into dummy variables
dfBoston = pd.get_dummies(dfBoston, prefix=['day', 'wx'], columns=['weekday', 'wx_code'])
dfBoston.columns = [x.lower() for x in dfBoston.columns]
dfBoston.rename(columns={'wx_r/s' : 'wx_rs'}, inplace = True)
dfBoston.columns
# Out:
# Index([u'dayofweek', u'major_holiday', u'month', u'year', u'corejobs', u'fiberjobs', u'd', u'day', u'holiday', u'day_fri', u'day_mon', u'day_sat', u'day_sun', u'day_thur', u'day_tue', u'day_wed', u'wx_clr', u'wx_fog', u'wx_mc', u'wx_pc', u'wx_rs', u'wx_rain', u'wx_snow', u'wx_wind'], dtype='object')

# %%
dfBoston[[u'day_mon', u'day_tue', u'day_wed', u'day_thur', u'day_fri', u'day_sat', u'day_sun', 
          u'wx_clr', u'wx_fog', u'wx_mc', u'wx_pc', u'wx_rs', u'wx_rain', u'wx_snow', u'wx_wind']].head()
# Out:
#                day_mon  day_tue  day_wed  day_thur  day_fri  day_sat  day_sun  \
# JOBCREATEDATE
# 2013-01-01           0        1        0         0        0        0        0
# 2013-01-02           0        0        1         0        0        0        0
# 2013-01-03           0        0        0         1        0        0        0
# 2013-01-04           0        0        0         0        1        0        0
# 2013-01-05           0        0        0         0        0        1        0
#
#                wx_clr  wx_fog  wx_mc  wx_pc  wx_rs  wx_rain  wx_snow  wx_wind
# JOBCREATEDATE
# 2013-01-01          0       0      1      0      0        0        0        0
# 2013-01-02          1       0      0      0      0        0        0        0
# 2013-01-03          0       0      0      1      0        0        0        0
# 2013-01-04          0       0      1      0      0        0        0        0
# 2013-01-05          0       0      1      0      0        0        0        0

# %%
for i in np.arange(1,8):
    dfBoston['corejobs' + str(i)] = dfBoston.corejobs.shift(i)
dfBoston.columns
# Out:
# Index([u'dayofweek', u'major_holiday', u'month', u'year', u'corejobs', u'fiberjobs', u'd', u'day', u'holiday', u'day_fri', u'day_mon', u'day_sat', u'day_sun', u'day_thur', u'day_tue', u'day_wed', u'wx_clr', u'wx_fog', u'wx_mc', u'wx_pc', u'wx_rs', u'wx_rain', u'wx_snow', u'wx_wind', u'corejobs1', u'corejobs2', u'corejobs3', u'corejobs4', u'corejobs5', u'corejobs6', u'corejobs7'], dtype='object')

# %%
#create a simple Linear Regression model to fit and predict the repair jobs
dfBoston = dfBoston.fillna(0)

dfBoston[[u'corejobs', u'corejobs1', u'corejobs2', u'corejobs3', u'corejobs4', u'corejobs5', u'corejobs6', u'corejobs7']].head(10)
# Out:
#                corejobs  corejobs1  corejobs2  corejobs3  corejobs4  \
# JOBCREATEDATE
# 2013-01-01           12          0          0          0          0
# 2013-01-02           89         12          0          0          0
# 2013-01-03           89         89         12          0          0
# 2013-01-04           79         89         89         12          0
# 2013-01-05           21         79         89         89         12
# 2013-01-06           10         21         79         89         89
# 2013-01-07           95         10         21         79         89
# 2013-01-08           77         95         10         21         79
# 2013-01-09           86         77         95         10         21
# 2013-01-10           88         86         77         95         10
#
#                corejobs5  corejobs6  corejobs7
# JOBCREATEDATE
# 2013-01-01             0          0          0
# 2013-01-02             0          0          0
# 2013-01-03             0          0          0
# 2013-01-04             0          0          0
# 2013-01-05             0          0          0
# 2013-01-06            12          0          0
# 2013-01-07            89         12          0
# 2013-01-08            89         89         12
# 2013-01-09            79         89         89
# 2013-01-10            21         79         89

# %%
Holidays = list(np.unique(dfBoston['holiday']))
Holidays.remove('N')

dfBoston['isholiday'] = map(lambda x: 1 if x in Holidays else 0, dfBoston['holiday'])
dfBoston['ishol_plus1'] = dfBoston.isholiday.shift(1)

dfBoston = dfBoston.fillna(0)

dfBoston[[u'isholiday', u'ishol_plus1']].head()
# Out:
#                isholiday  ishol_plus1
# JOBCREATEDATE
# 2013-01-01             1            0
# 2013-01-02             0            1
# 2013-01-03             0            0
# 2013-01-04             0            0
# 2013-01-05             0            0

# %%
f, ax = plt.subplots(figsize=(20, 20))
sns.corrplot(dfBoston[['day_mon', 'day_tue', 'day_wed', 'day_thur', 'day_fri', 'day_sat', 'day_sun', 'wx_clr', 'wx_fog', 'wx_mc', 
                       'wx_pc', 'wx_rs', 'wx_rain', 'wx_snow', 'wx_wind', 'isholiday', 'corejobs', 'fiberjobs']], diag_names=False, ax=ax);

# %% [markdown]
# ## Linear Regression - Building Model
#
# Explain All Variables vs Weather Variables vs Non Weather Variables
#
# Split the dataset
# - Training data set from 1/1/2013 - 9/30/2014
# - Validation data set from 10/1/2014 - 10/21/2014 (Latest 21 Days)

# %%
#define X and Y
X = dfBoston[[u'day_mon', u'day_tue', u'day_wed', u'day_thur', u'day_fri', u'day_sat', u'day_sun', 
           u'wx_clr', u'wx_fog', u'wx_mc', u'wx_pc', u'wx_rs', u'wx_rain', u'wx_snow', u'wx_wind', u'isholiday', u'ishol_plus1',
           u'corejobs1', u'corejobs2', u'corejobs3', u'corejobs4', u'corejobs5', u'corejobs6', u'corejobs7']]

Y = dfBoston['corejobs'].values

#split the data
trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
#split the data
train = dfBoston[dfBoston['d'] <= 0]
test = dfBoston[dfBoston['d'] > 0]

#all variables 
trainY = train['corejobs'].values
trainX = train[[u'day_mon', u'day_tue', u'day_wed', u'day_thur', u'day_fri', u'day_sat', u'day_sun', 
           u'wx_clr', u'wx_fog', u'wx_mc', u'wx_pc', u'wx_rs', u'wx_rain', u'wx_snow', u'wx_wind', u'isholiday', u'ishol_plus1',
           u'corejobs1', u'corejobs2', u'corejobs3', u'corejobs4', u'corejobs5', u'corejobs6', u'corejobs7']]

testY = test["corejobs"].values
testX = test[[u'day_mon', u'day_tue', u'day_wed', u'day_thur', u'day_fri', u'day_sat', u'day_sun', 
           u'wx_clr', u'wx_fog', u'wx_mc', u'wx_pc', u'wx_rs', u'wx_rain', u'wx_snow', u'wx_wind', u'isholiday', u'ishol_plus1',
           u'corejobs1', u'corejobs2', u'corejobs3', u'corejobs4', u'corejobs5', u'corejobs6', u'corejobs7']]

#weather variables
#define X and Y
wtrainY = train['corejobs'].values
wtrainX = train[[u'wx_clr', u'wx_fog', u'wx_mc', u'wx_pc', u'wx_rs', u'wx_rain', u'wx_snow', u'wx_wind']]

wtestY = test["corejobs"].values
wtestX = test[[u'wx_clr', u'wx_fog', u'wx_mc', u'wx_pc', u'wx_rs', u'wx_rain', u'wx_snow', u'wx_wind']]

#non weather variables
#define X and Y
nwtrainY = train['corejobs'].values
nwtrainX = train[[u'day_mon', u'day_tue', u'day_wed', u'day_thur', u'day_fri', u'day_sat', u'day_sun', u'isholiday', u'ishol_plus1',
           u'corejobs1', u'corejobs2', u'corejobs3', u'corejobs4', u'corejobs5', u'corejobs6', u'corejobs7']]

nwtestY = test["corejobs"].values
nwtestX = test[[u'day_mon', u'day_tue', u'day_wed', u'day_thur', u'day_fri', u'day_sat', u'day_sun', u'isholiday', u'ishol_plus1',
           u'corejobs1', u'corejobs2', u'corejobs3', u'corejobs4', u'corejobs5', u'corejobs6', u'corejobs7']]

# %%
print 'all variables'
print trainX.shape
print trainY.shape
print testX.shape
print testY.shape

print 'weather variables'
print wtrainX.shape
print wtrainY.shape
print wtestX.shape
print wtestY.shape

print 'non weather variables'
print nwtrainX.shape
print nwtrainY.shape
print nwtestX.shape
print nwtestY.shape
# Out:
# all variables
# (638, 24)
# (638L,)
# (11, 24)
# (11L,)
# weather variables
# (638, 8)
# (638L,)
# (11, 8)
# (11L,)
# non weather variables
# (638, 16)
# (638L,)
# (11, 16)
# (11L,)

# %%
#instantiate a linear regression model, and fit with X and y
allvarlinregr = linear_model.LinearRegression()
allvarlinregr = allvarlinregr.fit(trainX, trainY)

#predict the wins using test dataset
y_pred = allvarlinregr.predict(trainX)
#y_hat = allvarlinregr.predict(testX)

print y_pred.shape
print y_hat.shape

#coef_, intercept, standard error, t-test value, p value

#print coefficients for all the features
pd.DataFrame(zip(testX.columns, allvarlinregr.coef_), columns = ['Variables', 'estimatedCoeff'])
# Out:
# (638L,)
# (11L,)
#       Variables  estimatedCoeff
# 0       day_mon       38.044687
# 1       day_tue       13.615993
# 2       day_wed       12.654768
# 3      day_thur        5.205848
# 4       day_fri        3.362969
# 5       day_sat      -39.044924
# 6       day_sun      -33.839341
# 7        wx_clr        3.845023
# 8        wx_fog        8.340937
# 9         wx_mc        4.095675
# 10        wx_pc        1.931828
# 11        wx_rs       -5.227835
# 12      wx_rain       10.561994
# 13      wx_snow       -1.094663
# 14      wx_wind      -22.452960
# 15    isholiday      -52.009854
# 16  ishol_plus1       18.237440
# 17    corejobs1        0.382417
# 18    corejobs2        0.008660
# 19    corejobs3        0.082433
# 20    corejobs4        0.015468
# 21    corejobs5        0.021564
# 22    corejobs6        0.064169
# 23    corejobs7        0.042869

# %%
#why all coeff are same for weather variables???

#instantiate a linear regression model, and fit with X and y
wvarlinregr = linear_model.LinearRegression()
wvarlinregr = wvarlinregr.fit(wtrainX, wtrainY)

#predict the wins using test dataset
wy_pred = wvarlinregr.predict(wtrainX)
wy_hat = wvarlinregr.predict(wtestX)

print wy_pred.shape
print wy_hat.shape

#print coefficients for all the features
pd.DataFrame(zip(wtestX.columns, wvarlinregr.coef_), columns = ['Variables', 'estimatedCoeff'])
# Out:
# (638L,)
# (11L,)
#   Variables  estimatedCoeff
# 0    wx_clr   -3.072081e+14
# 1    wx_fog   -3.072081e+14
# 2     wx_mc   -3.072081e+14
# 3     wx_pc   -3.072081e+14
# 4     wx_rs   -3.072081e+14
# 5   wx_rain   -3.072081e+14
# 6   wx_snow   -3.072081e+14
# 7   wx_wind   -3.072081e+14

# %%
#instantiate a linear regression model, and fit with X and y
nwvarlinregr = linear_model.LinearRegression()
nwvarlinregr = nwvarlinregr.fit(nwtrainX, nwtrainY)

#predict the wins using test dataset
nwy_pred = nwvarlinregr.predict(nwtrainX)
nwy_hat = nwvarlinregr.predict(nwtestX)

print nwy_pred.shape
print nwy_hat.shape

#print coefficients for all the features
pd.DataFrame(zip(nwtestX.columns, nwvarlinregr.coef_), columns = ['Variables', 'estimatedCoeff'])
# Out:
# (638L,)
# (11L,)
#       Variables  estimatedCoeff
# 0       day_mon       38.554913
# 1       day_tue       14.506699
# 2       day_wed       12.442286
# 3      day_thur        4.390176
# 4       day_fri        2.511453
# 5       day_sat      -38.984535
# 6       day_sun      -33.420991
# 7     isholiday      -51.704083
# 8   ishol_plus1       17.479286
# 9     corejobs1        0.378965
# 10    corejobs2        0.024302
# 11    corejobs3        0.080052
# 12    corejobs4        0.012995
# 13    corejobs5        0.010502
# 14    corejobs6        0.057040
# 15    corejobs7        0.055523

# %% [markdown]
# ## Measure Model Performance
#
# Explain how we measure the model performance

# %%
#check the accuracy on the training set
print 'Train Score', allvarlinregr.score(trainX, trainY)

#Calculate the Average Squared Resuduals / Mean Squared Error
print sklearn.metrics.mean_squared_error(trainY, y_pred)

#calculate the residuals
residual = trainY - y_pred

#take absolute residuals
abs_residual = np.abs(residual);

mean_abs_residual = np.mean(abs_residual)
min_abs_residual = np.min(abs_residual)
max_abs_residual = np.max(abs_residual)
std_abs_residual = np.std(abs_residual)
corejob_actual = np.mean(trainY)

error_rate = mean_abs_residual / corejob_actual
accuracy = 1 - mean_abs_residual / corejob_actual

print residual.shape
#print 'residual', residual
#print 'abs residual', abs_residual
print 'mean residual', mean_abs_residual
print 'min residual', min_abs_residual
print 'max residual', max_abs_residual
print 'std residual', std_abs_residual
print 'actual corejobs', corejob_actual
print 'error_rate', error_rate
print 'accuracy', accuracy
# Out:
# Train Score 0.809112759656
# 201.597260366
# (638L,)
# mean residual 10.3935711795
# min residual 1.42108547152e-14
# max residual 60.5294924688
# std residual 9.67320725004
# actual corejobs 59.6222570533
# error_rate 0.174323678659
# accuracy 0.825676321341

# %%
plt.figure(figsize=(15,8))
plt.scatter(trainX.index, residual, s=200, c='b', marker='^', alpha=0.5)
plt.show()

# %%
#check the accuracy on the training set
print 'Test Score', allvarlinregr.score(testX, testY)

#Calculate the Average Squared Resuduals / Mean Squared Error
print sklearn.metrics.mean_squared_error(testY, y_hat)

#calculate the residuals
tresidual = testY - y_hat

#take absolute residuals
tabs_residual = np.abs(residual);

tmean_abs_residual = np.mean(abs_residual)
tmin_abs_residual = np.min(abs_residual)
tmax_abs_residual = np.max(abs_residual)
tstd_abs_residual = np.std(abs_residual)
tcorejob_actual = np.mean(trainY)

terror_rate = mean_abs_residual / corejob_actual
taccuracy = 1 - mean_abs_residual / corejob_actual

print residual.shape
#print 'residual', tresidual
#print 'abs residual', tabs_residual
print 'mean residual', tmean_abs_residual
print 'min residual', tmin_abs_residual
print 'max residual', tmax_abs_residual
print 'std residual', tstd_abs_residual
print 'actual corejobs', tcorejob_actual
print 'error_rate', terror_rate
print 'accuracy', taccuracy
# Out:
# Test Score 0.678974723331
# 205.270459966
# (638L,)
# mean residual 10.3935711795
# min residual 1.42108547152e-14
# max residual 60.5294924688
# std residual 9.67320725004
# actual corejobs 59.6222570533
# error_rate 0.174323678659
# accuracy 0.825676321341

# %%
plt.figure(figsize=(15,8))
#plt.ylim()???
plt.scatter(testX.index, tresidual, s=200, c='g', marker='^', alpha=0.5)
plt.show()

# %%
pd.ols(x=trainX, y=trainY)
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <day_mon> + <day_tue> + <day_wed> + <day_thur> + <day_fri>
#              + <day_sat> + <day_sun> + <wx_clr> + <wx_fog> + <wx_mc> + <wx_pc> + <wx_rs>
#              + <wx_rain> + <wx_snow> + <wx_wind> + <isholiday> + <ishol_plus1>
#              + <corejobs1> + <corejobs2> + <corejobs3> + <corejobs4> + <corejobs5>
#              + <corejobs6> + <corejobs7> + <intercept>
#
# Number of Observations:         638
# Number of Degrees of Freedom:   23
#
# R-squared:         0.8091
# Adj R-squared:     0.8023
#
# Rmse:             14.4616
#
# F-stat (24, 615):   118.4908, p-value:     0.0000
#
# Degrees of Freedom: model 22, resid 615
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#        day_mon    40.3128 12049081.3569       0.00     1.0000 -23616159.1467 23616239.7723
#        day_tue    15.8841 12049081.3569       0.00     1.0000 -23616183.5754 23616215.3436
#        day_wed    14.9229 12049081.3569       0.00     1.0000 -23616184.5366 23616214.3823
#       day_thur     7.4740 12049081.3569       0.00     1.0000 -23616191.9855 23616206.9334
#        day_fri     5.6311 12049081.3569       0.00     1.0000 -23616193.8284 23616205.0905
# --------------------------------------------------------------------------------
#        day_sat   -36.7768 12049081.3569      -0.00     1.0000 -23616236.2363 23616162.6827
#        day_sun   -31.5712 12049081.3569      -0.00     1.0000 -23616231.0307 23616167.8882
#         wx_clr     5.8296 42753298.7254       0.00     1.0000 -83796459.6722 83796471.3314
#         wx_fog    10.3255 42753298.7254       0.00     1.0000 -83796455.1763 83796475.8273
#          wx_mc     6.0803 42753298.7254       0.00     1.0000 -83796459.4215 83796471.5821
# --------------------------------------------------------------------------------
#          wx_pc     3.9164 42753298.7254       0.00     1.0000 -83796461.5854 83796469.4182
#          wx_rs    -3.2432 42753298.7254      -0.00     1.0000 -83796468.7450 83796462.2586
#        wx_rain    12.5466 42753298.7254       0.00     1.0000 -83796452.9552 83796478.0484
#        wx_snow     0.8899 42753298.7254       0.00     1.0000 -83796464.6119 83796466.3917
#        wx_wind   -20.4684 42753298.7254      -0.00     1.0000 -83796485.9702 83796445.0334
# --------------------------------------------------------------------------------
#      isholiday   -52.0099     3.6305     -14.33     0.0000   -59.1257   -44.8940
#    ishol_plus1    18.2374     4.1797       4.36     0.0000    10.0452    26.4296
#      corejobs1     0.3824     0.0391       9.78     0.0000     0.3058     0.4590
#      corejobs2     0.0087     0.0361       0.24     0.8107    -0.0622     0.0795
#      corejobs3     0.0824     0.0356       2.31     0.0211     0.0126     0.1523
# --------------------------------------------------------------------------------
#      corejobs4     0.0155     0.0357       0.43     0.6651    -0.0545     0.0855
#      corejobs5     0.0216     0.0358       0.60     0.5472    -0.0486     0.0917
#      corejobs6     0.0642     0.0354       1.81     0.0701    -0.0052     0.1335
#      corejobs7     0.0429     0.0332       1.29     0.1971    -0.0222     0.1079
#      intercept    15.8768 11493055.6836       0.00     1.0000 -22526373.2631 22526405.0166
# ---------------------------------End of Summary---------------------------------

# %%
pd.ols(x=testX, y=testY)
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <day_mon> + <day_tue> + <day_wed> + <day_thur> + <day_fri>
#              + <day_sat> + <day_sun> + <wx_clr> + <wx_fog> + <wx_mc> + <wx_pc> + <wx_rs>
#              + <wx_rain> + <wx_snow> + <wx_wind> + <isholiday> + <ishol_plus1>
#              + <corejobs1> + <corejobs2> + <corejobs3> + <corejobs4> + <corejobs5>
#              + <corejobs6> + <corejobs7> + <intercept>
#
# Number of Observations:         11
# Number of Degrees of Freedom:   11
#
# R-squared:         1.0000
# Adj R-squared:        nan
#
# Rmse:                 inf
#
# F-stat (24, 0):        nan, p-value:        nan
#
# Degrees of Freedom: model 11, resid 0
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#        day_mon    65.9801        inf       0.00        nan       -inf        inf
#        day_tue     2.4088        inf       0.00        nan       -inf        inf
#        day_wed    16.3014        inf       0.00        nan       -inf        inf
#       day_thur   -13.6986        inf      -0.00        nan       -inf        inf
#        day_fri    -6.0326        inf      -0.00        nan       -inf        inf
# --------------------------------------------------------------------------------
#        day_sat   -18.1897        inf      -0.00        nan       -inf        inf
#        day_sun     4.6579        inf       0.00        nan       -inf        inf
#         wx_clr    14.5111        inf       0.00        nan       -inf        inf
#         wx_fog     0.0000        nan        nan        nan        nan        nan
#          wx_mc    10.9302        inf       0.00        nan       -inf        inf
# --------------------------------------------------------------------------------
#          wx_pc     2.4088        inf       0.00        nan       -inf        inf
#          wx_rs     0.0000        nan        nan        nan        nan        nan
#        wx_rain    23.5773        inf       0.00        nan       -inf        inf
#        wx_snow     0.0000        nan        nan        nan        nan        nan
#        wx_wind     0.0000        nan        nan        nan        nan        nan
# --------------------------------------------------------------------------------
#      isholiday     0.0000        nan        nan        nan        nan        nan
#    ishol_plus1     0.0000        nan        nan        nan        nan        nan
#      corejobs1     1.1382        inf       0.00        nan       -inf        inf
#      corejobs2    -1.2610        inf      -0.00        nan       -inf        inf
#      corejobs3     0.7986        inf       0.00        nan       -inf        inf
# --------------------------------------------------------------------------------
#      corejobs4    -0.8671        inf      -0.00        nan       -inf        inf
#      corejobs5     0.0177        inf       0.00        nan       -inf        inf
#      corejobs6    -0.3184        inf      -0.00        nan       -inf        inf
#      corejobs7     0.2225        inf       0.00        nan       -inf        inf
#      intercept    51.4274        inf       0.00        nan       -inf        inf
# ---------------------------------End of Summary---------------------------------

# %%
sns.coefplot("corejobs ~ day_mon + day_tue + day_wed + day_thur + day_fri + day_sat + day_sun \
             + wx_clr + wx_fog + wx_mc + wx_pc + wx_rs + wx_rain + wx_snow + wx_wind + isholiday + ishol_plus1 \
             + corejobs1 + corejobs2 + corejobs3 + corejobs4 + corejobs5 + corejobs6 + corejobs7", dfBoston);
#sns.axlabel(rotation=45)

# %%
#sns.residplot()

# %%
#sns.regplot()

# %%
#stepwise regression (backward)
